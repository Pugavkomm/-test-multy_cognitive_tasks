# %% [markdown]
# # Two task network
#
# Network has eight inputs:
#
# 1. The fixation.
# 1. $u_{rule}^{1}$
# 1. $u_{rule}^{2}$
# 1. The first context mod.
# 1. The second ontext mod.
# 1. The first context status.
# 1. The second context status.
# 1. The Romo signals.
#
# Network has five outputs:
# 1. The fixation.
# 1. The first context output.
# 1. The second context output.
# 1. The first Romo task output.
# 1. The second Romo task output.
#
#
# <div>
# <img src="./images/Sheme.png" width="300"/>
# </div>
#
# > Learning rule: superspike
#
# > Neuron type: Alif

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt  # for analys
from cgtasknet.net.lifadex import SNNlifadex
from cgtasknet.tasks.tasks import MultyTask
from norse.torch.functional.lif_adex import LIFAdExParameters

# %% [markdown]
# ## Step -1: Create dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device('cpu')
print(f'Device: {("gpu (cuda)" if device.type=="cuda" else "cpu")}')
# Out:
# Device: gpu (cuda)

# %%
batch_size = 100
number_of_tasks = 1
task_list = [("WorkingMemory", dict()), (("ContextDM", dict()))]
tasks = dict(task_list)
Task = MultyTask(tasks=tasks, batch_size=batch_size)

# %% [markdown]
# ## Step 1.1: Create model

# %%
feature_size, output_size = Task.feature_and_act_size[0]
hidden_size = 400

neuron_parameters = LIFAdExParameters(
    tau_ada_inv=torch.Tensor([2]).to(device), alpha=100
)
model = SNNlifadex(
    feature_size, hidden_size, output_size, neuron_parameters=neuron_parameters
).to(device)

# %% [markdown]
# ## Step 1.2: Save pre-learning weights

# %%
weights_pre_l = []
with torch.no_grad():
    for name, param in model.named_parameters():
        if param.requires_grad:
            weights_pre_l.append((param).cpu().numpy())

# %% [markdown]
# ## Step 2: loss and creterion

# %%
learning_rate = 5e-3


class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))


criterion = RMSELoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.8, 0.85))
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.8, 0.85))

# %% [markdown]
# ## Step 3: Train loop

# %%
# %matplotlib
plt.ion
fig = plt.figure()
ax = fig.add_subplot(111)
fig2 = plt.figure()

ax2 = fig2.add_subplot(111)
ax2.set_title("lifadex")
ax.set_title("lifadex")
inputs, target_outputs = Task.dataset(number_of_tasks)
(line1,) = ax.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 1], "b-")
(line2,) = ax.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 2], "r-")
(line3,) = ax.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 1], "b-")
(line4,) = ax.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 2], "r-")
(line21,) = ax2.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 1], "b-")
(line22,) = ax2.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 2], "r-")
(line23,) = ax2.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 1], "b-")
(line24,) = ax2.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 2], "r-")
ax.set_ylim([-0.5, 1.5])
ax.set_xlim([0, len(inputs) * 2])
ax2.set_ylim([-0.5, 1.5])
ax2.set_xlim([0, len(inputs) * 2])
running_loss = 0
fig.canvas.draw()
fig.canvas.flush_events()
fig2.canvas.draw()
fig2.canvas.flush_events()
for i in range(2000):
    inputs, target_outputs = Task.dataset(number_of_tasks)
    inputs += np.random.normal(0, 0.01, size=(inputs.shape))
    inputs = torch.from_numpy(inputs).type(torch.float).to(device)
    target_outputs = torch.from_numpy(target_outputs).type(torch.float).to(device)

    # zero the parameter gradients
    optimizer.zero_grad()

    # forward + backward + optimize
    outputs, states = model(inputs)

    loss = criterion(outputs, target_outputs)
    loss.backward()
    optimizer.step()

    # print statistics
    running_loss += loss.item()
    if i % 10 == 9:
        print("epoch: {:d} loss: {:0.5f}".format(i + 1, running_loss / 10))
        running_loss = 0.0
        with torch.no_grad():
            inputs, target_outputs = Task.dataset(number_of_tasks)

            inputs = torch.from_numpy(inputs).type(torch.float).to(device)
            target_outputs = (
                torch.from_numpy(target_outputs).type(torch.float).to(device)
            )
            outputs, states = model(inputs)
            loss = criterion(outputs, target_outputs)

            print("test loss: {:0.5f}".format(loss.item()))
        for_plot = outputs.detach().cpu().numpy()[:, 0, :]
        line1.set_xdata(np.arange(0, len(for_plot), 1))
        line2.set_xdata(np.arange(0, len(for_plot), 1))
        line3.set_xdata(np.arange(0, len(for_plot), 1))
        line4.set_xdata(np.arange(0, len(for_plot), 1))
        line21.set_xdata(np.arange(0, len(for_plot), 1))
        line22.set_xdata(np.arange(0, len(for_plot), 1))
        line23.set_xdata(np.arange(0, len(for_plot), 1))
        line24.set_xdata(np.arange(0, len(for_plot), 1))

        line1.set_ydata(for_plot[:, 1])
        line2.set_ydata(for_plot[:, 2])
        line3.set_ydata(target_outputs.detach().cpu().numpy()[:, 0, 1])
        line4.set_ydata(target_outputs.detach().cpu().numpy()[:, 0, 2])

        line21.set_ydata(for_plot[:, 3])
        line22.set_ydata(for_plot[:, 4])
        line23.set_ydata(target_outputs.detach().cpu().numpy()[:, 0, 3])
        line24.set_ydata(target_outputs.detach().cpu().numpy()[:, 0, 4])

    fig.canvas.draw()
    fig.canvas.flush_events()
    fig2.canvas.draw()
    fig2.canvas.flush_events()


print("Finished Training")
# Out:
# Using matplotlib backend: TkAgg
# epoch: 10 loss: 0.14391
# test loss: 0.22344
# epoch: 20 loss: 0.18197
# test loss: 0.25000
# epoch: 30 loss: 0.16428
# test loss: 0.25077
# epoch: 40 loss: 0.12079
# test loss: 0.10614
# epoch: 50 loss: 0.16430
# test loss: 0.23679
# epoch: 60 loss: 0.19000
# test loss: 0.10002
# epoch: 70 loss: 0.13279
# test loss: 0.21823
# epoch: 80 loss: 0.17385
# test loss: 0.23196
# epoch: 90 loss: 0.18853
# test loss: 0.08859
# epoch: 100 loss: 0.18036
# test loss: 0.11207
# epoch: 110 loss: 0.13759
# test loss: 0.25810
# epoch: 120 loss: 0.19069
# test loss: 0.22177
# epoch: 130 loss: 0.17550
# test loss: 0.09891
# epoch: 140 loss: 0.14882
# test loss: 0.09601
# epoch: 150 loss: 0.15589
# test loss: 0.09187
# epoch: 160 loss: 0.16250
# test loss: 0.22446
# epoch: 170 loss: 0.15147
# test loss: 0.09108
# epoch: 180 loss: 0.12212
# test loss: 0.09076
# epoch: 190 loss: 0.15048
# test loss: 0.10225
# epoch: 200 loss: 0.17007
# test loss: 0.24425
# epoch: 210 loss: 0.18726
# test loss: 0.11486
# epoch: 220 loss: 0.19390
# test loss: 0.24171
# epoch: 230 loss: 0.16546
# test loss: 0.09241
# epoch: 240 loss: 0.19984
# test loss: 0.13846
# epoch: 250 loss: 0.16932
# test loss: 0.24310
# epoch: 260 loss: 0.15902
# test loss: 0.23087
# epoch: 270 loss: 0.15440
# test loss: 0.21980
# epoch: 280 loss: 0.15799
# test loss: 0.23294
# epoch: 290 loss: 0.19469
# test loss: 0.21013
# epoch: 300 loss: 0.17276
# test loss: 0.08991
# epoch: 310 loss: 0.18037
# test loss: 0.23979
# epoch: 320 loss: 0.19627
# test loss: 0.16260
# epoch: 330 loss: 0.19016
# test loss: 0.22533
# epoch: 340 loss: 0.18404
# test loss: 0.09712
# epoch: 350 loss: 0.18653
# test loss: 0.24676
# epoch: 360 loss: 0.13237
# test loss: 0.09208
# epoch: 370 loss: 0.14693
# test loss: 0.22913
# epoch: 380 loss: 0.19580
# test loss: 0.23497
# epoch: 390 loss: 0.13507
# test loss: 0.22820
# epoch: 400 loss: 0.16859
# test loss: 0.08753
# epoch: 410 loss: 0.21333
# test loss: 0.22364
# epoch: 420 loss: 0.16519
# test loss: 0.10748
# epoch: 430 loss: 0.14365
# test loss: 0.10874
# epoch: 440 loss: 0.16565
# test loss: 0.25531
# epoch: 450 loss: 0.15003
# test loss: 0.23458
# epoch: 460 loss: 0.14367
# test loss: 0.07228
# epoch: 470 loss: 0.17137
# test loss: 0.08543
# epoch: 480 loss: 0.15985
# test loss: 0.09017
# epoch: 490 loss: 0.14387
# test loss: 0.22837
# epoch: 500 loss: 0.16411
# test loss: 0.08280
# epoch: 510 loss: 0.16925
# test loss: 0.07223
# epoch: 520 loss: 0.17492
# test loss: 0.22977
# epoch: 530 loss: 0.14547
# test loss: 0.22590
# epoch: 540 loss: 0.15835
# test loss: 0.08407
# epoch: 550 loss: 0.14576
# test loss: 0.07868
# epoch: 560 loss: 0.16345
# test loss: 0.23043
# epoch: 570 loss: 0.20704
# test loss: 0.21951
# epoch: 580 loss: 0.16842
# test loss: 0.24274
# epoch: 590 loss: 0.13586
# test loss: 0.22829
# epoch: 600 loss: 0.14391
# test loss: 0.08446
# epoch: 610 loss: 0.16149
# test loss: 0.12010
# epoch: 620 loss: 0.16666
# test loss: 0.08871
# epoch: 630 loss: 0.15774
# test loss: 0.22854
# epoch: 640 loss: 0.18761
# test loss: 0.08370
# epoch: 650 loss: 0.18033
# test loss: 0.12943
# epoch: 660 loss: 0.14845
# test loss: 0.08366
# epoch: 670 loss: 0.17086
# test loss: 0.08733
# epoch: 680 loss: 0.16363
# test loss: 0.07901
# epoch: 690 loss: 0.14140
# test loss: 0.24874
# epoch: 700 loss: 0.15119
# test loss: 0.08386
# epoch: 710 loss: 0.15909
# test loss: 0.21970
# epoch: 720 loss: 0.13194
# test loss: 0.08697
# epoch: 730 loss: 0.11427
# test loss: 0.07908
# epoch: 740 loss: 0.13489
# test loss: 0.24051
# epoch: 750 loss: 0.18778
# test loss: 0.10019
# epoch: 760 loss: 0.20626
# test loss: 0.24862
# epoch: 770 loss: 0.15484
# test loss: 0.22459
# epoch: 780 loss: 0.13112
# test loss: 0.09610
# epoch: 790 loss: 0.15050
# test loss: 0.08590
# epoch: 800 loss: 0.19219
# test loss: 0.22910
# epoch: 810 loss: 0.18500
# test loss: 0.06650
# epoch: 820 loss: 0.18125
# test loss: 0.23431
# epoch: 830 loss: 0.17470
# test loss: 0.22761
# epoch: 840 loss: 0.19034
# test loss: 0.08640
# epoch: 850 loss: 0.14764
# test loss: 0.09400
# epoch: 860 loss: 0.16599
# test loss: 0.19961
# epoch: 870 loss: 0.20401
# test loss: 0.14098
# epoch: 880 loss: 0.16266
# test loss: 0.11800
# epoch: 890 loss: 0.15572
# test loss: 0.09903
# epoch: 900 loss: 0.17823
# test loss: 0.07437
# epoch: 910 loss: 0.14326
# test loss: 0.07833
# epoch: 920 loss: 0.16061
# test loss: 0.21860
# epoch: 930 loss: 0.15903
# test loss: 0.08636
# epoch: 940 loss: 0.13325
# test loss: 0.08471
# epoch: 950 loss: 0.18428
# test loss: 0.09204
# epoch: 960 loss: 0.17580
# test loss: 0.11109
# epoch: 970 loss: 0.16167
# test loss: 0.08105
# epoch: 980 loss: 0.14521
# test loss: 0.21573
# epoch: 990 loss: 0.14274
# test loss: 0.08250
# epoch: 1000 loss: 0.11392
# test loss: 0.23650
# epoch: 1010 loss: 0.18279
# test loss: 0.21559
# epoch: 1020 loss: 0.14999
# test loss: 0.08762
# epoch: 1030 loss: 0.15700
# test loss: 0.10363
# epoch: 1040 loss: 0.13344
# test loss: 0.07405
# epoch: 1050 loss: 0.12773
# test loss: 0.08571
# epoch: 1060 loss: 0.15908
# test loss: 0.08982
# epoch: 1070 loss: 0.16616
# test loss: 0.23500
# epoch: 1080 loss: 0.12770
# test loss: 0.23584
# epoch: 1090 loss: 0.19102
# test loss: 0.19399
# epoch: 1100 loss: 0.16639
# test loss: 0.07491
# epoch: 1110 loss: 0.15545
# test loss: 0.07874
# epoch: 1120 loss: 0.16179
# test loss: 0.23202
# epoch: 1130 loss: 0.14257
# test loss: 0.08230
# epoch: 1140 loss: 0.14019
# test loss: 0.25904
# epoch: 1150 loss: 0.13185
# test loss: 0.09208
# epoch: 1160 loss: 0.13108
# test loss: 0.07862
# epoch: 1170 loss: 0.12116
# test loss: 0.24281
# epoch: 1180 loss: 0.16738
# test loss: 0.08968
# epoch: 1190 loss: 0.17541
# test loss: 0.09683
# epoch: 1200 loss: 0.17002
# test loss: 0.09655
# epoch: 1210 loss: 0.14541
# test loss: 0.09291
# epoch: 1220 loss: 0.17480
# test loss: 0.22844
# epoch: 1230 loss: 0.16818
# test loss: 0.22250
# epoch: 1240 loss: 0.17113
# test loss: 0.09075
# epoch: 1250 loss: 0.17428
# test loss: 0.19405
# epoch: 1260 loss: 0.11276
# test loss: 0.20549
# epoch: 1270 loss: 0.15196
# test loss: 0.08081
# epoch: 1280 loss: 0.15335
# test loss: 0.20710
# epoch: 1290 loss: 0.14600
# test loss: 0.25419
# epoch: 1300 loss: 0.12636
# test loss: 0.22127
# epoch: 1310 loss: 0.15750
# test loss: 0.07228
# epoch: 1320 loss: 0.12270
# test loss: 0.23153
# epoch: 1330 loss: 0.16312
# test loss: 0.22787
# epoch: 1340 loss: 0.14738
# test loss: 0.06287
# epoch: 1350 loss: 0.20078
# test loss: 0.08698
# epoch: 1360 loss: 0.19156
# test loss: 0.22479
# epoch: 1370 loss: 0.17262
# test loss: 0.07371
# epoch: 1380 loss: 0.17856
# test loss: 0.11058
# epoch: 1390 loss: 0.18805
# test loss: 0.11251
# epoch: 1400 loss: 0.12434
# test loss: 0.07312
# epoch: 1410 loss: 0.14610
# test loss: 0.24257
# epoch: 1420 loss: 0.13343
# test loss: 0.22847
# epoch: 1430 loss: 0.14031
# test loss: 0.07701
# epoch: 1440 loss: 0.17211
# test loss: 0.07583
# epoch: 1450 loss: 0.17406
# test loss: 0.22004
# epoch: 1460 loss: 0.19478
# test loss: 0.23517
# epoch: 1470 loss: 0.18135
# test loss: 0.09375
# epoch: 1480 loss: 0.12855
# test loss: 0.23131
# epoch: 1490 loss: 0.14641
# test loss: 0.22455
# epoch: 1500 loss: 0.12952
# test loss: 0.09272
# epoch: 1510 loss: 0.18701
# test loss: 0.09560
# epoch: 1520 loss: 0.16509
# test loss: 0.22275
# epoch: 1530 loss: 0.11167
# test loss: 0.22004
# epoch: 1540 loss: 0.17167
# test loss: 0.23995
# epoch: 1550 loss: 0.16039
# test loss: 0.07857
# epoch: 1560 loss: 0.11104
# test loss: 0.23168
# epoch: 1570 loss: 0.21417
# test loss: 0.11314
# epoch: 1580 loss: 0.16614
# test loss: 0.20934
# epoch: 1590 loss: 0.12851
# test loss: 0.08536
# epoch: 1600 loss: 0.17474
# test loss: 0.10801
# epoch: 1610 loss: 0.11531
# test loss: 0.22972
# epoch: 1620 loss: 0.15559
# test loss: 0.10836
# epoch: 1630 loss: 0.15793
# test loss: 0.23145
# epoch: 1640 loss: 0.16107
# test loss: 0.21875
# epoch: 1650 loss: 0.18002
# test loss: 0.22316
# epoch: 1660 loss: 0.15411
# test loss: 0.24242
# epoch: 1670 loss: 0.14868
# test loss: 0.22596
# epoch: 1680 loss: 0.18648
# test loss: 0.24873
# epoch: 1690 loss: 0.18318
# test loss: 0.21492
# epoch: 1700 loss: 0.19204
# test loss: 0.12530
# epoch: 1710 loss: 0.15477
# test loss: 0.09857
# epoch: 1720 loss: 0.11230
# test loss: 0.08655
# epoch: 1730 loss: 0.14242
# test loss: 0.23498
# epoch: 1740 loss: 0.19043
# test loss: 0.12469
# epoch: 1750 loss: 0.14209
# test loss: 0.23422
# epoch: 1760 loss: 0.16415
# test loss: 0.21974
# epoch: 1770 loss: 0.17381
# test loss: 0.09093
# epoch: 1780 loss: 0.16863
# test loss: 0.08915
# epoch: 1790 loss: 0.16187
# test loss: 0.23720
# epoch: 1800 loss: 0.15453
# test loss: 0.07656
# epoch: 1810 loss: 0.14000
# test loss: 0.23760
# epoch: 1820 loss: 0.14120
# test loss: 0.09107
# epoch: 1830 loss: 0.13627
# test loss: 0.07480
# epoch: 1840 loss: 0.14146
# test loss: 0.10416
# epoch: 1850 loss: 0.21408
# test loss: 0.11297
# epoch: 1860 loss: 0.20482
# test loss: 0.23777
# epoch: 1870 loss: 0.18027
# test loss: 0.24408
# epoch: 1880 loss: 0.15720
# test loss: 0.09382
# epoch: 1890 loss: 0.19255
# test loss: 0.21115
# epoch: 1900 loss: 0.18901
# test loss: 0.09236
# epoch: 1910 loss: 0.12660
# test loss: 0.22898
# epoch: 1920 loss: 0.19504
# test loss: 0.23340
# epoch: 1930 loss: 0.19620
# test loss: 0.08505
# epoch: 1940 loss: 0.18422
# test loss: 0.21977
# epoch: 1950 loss: 0.19475
# test loss: 0.09992
# epoch: 1960 loss: 0.18559
# test loss: 0.08175
# epoch: 1970 loss: 0.15986
# test loss: 0.23439
# epoch: 1980 loss: 0.17334
# test loss: 0.22308
# epoch: 1990 loss: 0.15418
# test loss: 0.07663
# epoch: 2000 loss: 0.12593
# test loss: 0.22103
# Finished Training

# %%
# torch.save(model.state_dict(), "lif_adex_romo_and_ctx_1510_iterations_steps_lr_1e-3")

# %%
if False:
    model.load_state_dict(
        torch.load("lif_adex_romo_and_ctx_1510_iterations_steps_lr_1e-3")
    )

# %%
Taskplot = MultyTask(tasks=tasks, batch_size=1)
inputs, target_outputs = Taskplot.dataset(10)
inputs += np.random.normal(0, 0.01, size=(inputs.shape))
inputs = torch.from_numpy(inputs).type(torch.float).to(device)
target_outputs = torch.from_numpy(target_outputs).type(torch.float).to(device)
outputs, states = model(inputs)

# %%
# %matplotlib inline
for i in range(inputs.shape[2]):
    plt.plot(inputs[:, 0, i].detach().cpu().numpy(), label=fr"$u_{i + 1}$")
    plt.legend()
    plt.show()
    plt.close()
for i in range(outputs.shape[2]):
    plt.plot(outputs[:, 0, i].detach().cpu().numpy(), label=fr"$u_{i + 1}$")
    plt.plot(
        target_outputs[:, 0, i].detach().cpu().numpy(), label=fr"$u^{{target}}_{i + 1}$"
    )
    plt.legend()
    plt.show()
    plt.close()
