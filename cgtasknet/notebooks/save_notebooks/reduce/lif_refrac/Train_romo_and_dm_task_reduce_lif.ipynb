# %% [markdown]
# # Two task network
#
# ## Network has some inputs
#
# 1. The fixation.
# 1. The first context mod.
# 1. The second ontext mod.
#
# ## Network has five outputs
# 1. The fixation.
# 1. The first output.
# 1. The second output
#
#
#
#
# <div>
# <img src="./images/Sheme.png" width="300"/>
# </div>
#
# > Learning rule: superspike
#
# > Neuron type: Lif + refrac
#
# > Task: romo and dm task.

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt  # for analys
from cgtasknet.net.lifrefrac import SNNLifRefrac
from cgtasknet.tasks.reduce import MultyReduceTasks, DefaultParams
from norse.torch.functional.lif_refrac import LIFRefracParameters
from norse.torch.functional.lif import LIFParameters

# from norse.torch import LIF

# %% [markdown]
# ## Step -1: Create dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device('cpu')
print(f'Device: {("gpu (cuda)" if device.type=="cuda" else "cpu")}')
# Out:
# Device: gpu (cuda)

# %%
batch_size = 30
number_of_tasks = 4
romo_parameters = DefaultParams("RomoTask").generate_params()
romo_parameters["delay"] = 0.1
romo_parameters["trial_time"] = 0.15
romo_parameters["n_mods"] = 1

dm_parameters = DefaultParams("DMTask").generate_params()
dm_parameters["n_mods"] = 1
task_list = ["RomoTask1", "DMTask1"]

tasks_parameters = dict(
    [
        (task_list[0], romo_parameters),
        (task_list[1], dm_parameters),
    ]
)

Task = MultyReduceTasks(
    tasks=tasks_parameters,
    batch_size=batch_size,
    number_of_inputs=1,
    delay_between_trial=500,
)
Task_test = MultyReduceTasks(
    tasks=tasks_parameters, batch_size=1, number_of_inputs=1, delay_between_trial=500
)

# %% [markdown]
# ## Step 1.1: Create model

# %%
feature_size, output_size = Task.feature_and_act_size
hidden_size = 400

neuron_parameters = LIFRefracParameters(
    LIFParameters(
        tau_mem_inv=torch.as_tensor(1 / 0.01).to(device),
        alpha=torch.as_tensor(100),
        method="super",
        v_th=torch.as_tensor(0.65).to(device),
    ),
    rho_reset=torch.as_tensor(1),
)
model = SNNLifRefrac(
    feature_size,
    hidden_size,
    output_size,
    neuron_parameters=neuron_parameters,
    tau_filter_inv=500,
).to(device)

# %% [markdown]
# ## Step 1.2: Save pre-learning weights

# %%
weights_pre_l = []
with torch.no_grad():
    for name, param in model.named_parameters():
        if param.requires_grad:
            weights_pre_l.append((param).cpu().numpy())

# %% [markdown]
# ## Step 2: loss and creterion

# %%
learning_rate = 1e-3


class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat, y))


criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Step 3: Train loop

# %%
# %matplotlib
plt.ion
fig = plt.figure()
ax = fig.add_subplot(111)

ax.set_title("lif")
inputs, target_outputs = Task.dataset(number_of_tasks)
(line1,) = ax.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 1], "b-")
(line2,) = ax.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 2], "r-")
(line3,) = ax.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 1], "b-")
(line4,) = ax.plot(np.arange(0, len(target_outputs)), target_outputs[:, 0, 2], "r-")
ax.set_ylim([-0.5, 1.5])
ax.set_xlim([0, len(inputs)])
running_loss = 0
fig.canvas.draw()
fig.canvas.flush_events()
for i in range(4000):
    inputs, target_outputs = Task.dataset(number_of_tasks)
    # inputs = inputs * 2 - 1
    inputs += np.random.normal(0, 0.01, size=(inputs.shape))
    inputs = torch.from_numpy(inputs).type(torch.float).to(device)
    target_outputs = torch.from_numpy(target_outputs).type(torch.float).to(device)
    # with torch.no_grad():
    #    inputs[:, :, 1:3] = layer_inputs(inputs[:, :, 1:3])[0]
    # zero the parameter gradients
    optimizer.zero_grad()

    # forward + backward + optimize
    outputs, states = model(inputs)

    loss = criterion(outputs, target_outputs)
    loss.backward()
    optimizer.step()

    # print statistics
    running_loss += loss.item()
    if i % 10 == 9:
        print("epoch: {:d} loss: {:0.5f}".format(i + 1, running_loss / 10))
        running_loss = 0.0
        with torch.no_grad():
            inputs, target_outputs = Task_test.dataset(number_of_tasks)

            inputs = torch.from_numpy(inputs).type(torch.float).to(device)
            target_outputs = (
                torch.from_numpy(target_outputs).type(torch.float).to(device)
            )
            outputs, states = model(inputs)
            loss = criterion(outputs, target_outputs)

            print("test loss: {:0.5f}".format(loss.item()))
        for_plot = outputs.detach().cpu().numpy()[:, 0, :]
        line1.set_xdata(np.arange(0, len(for_plot), 1))
        line2.set_xdata(np.arange(0, len(for_plot), 1))
        line3.set_xdata(np.arange(0, len(for_plot), 1))
        line4.set_xdata(np.arange(0, len(for_plot), 1))

        line1.set_ydata(for_plot[:, 1])
        line2.set_ydata(for_plot[:, 2])
        line3.set_ydata(target_outputs.detach().cpu().numpy()[:, 0, 1])
        line4.set_ydata(target_outputs.detach().cpu().numpy()[:, 0, 2])
    fig.canvas.draw()
    fig.canvas.flush_events()
print("Finished Training")
# Out:
# Using matplotlib backend: TkAgg
# epoch: 10 loss: 0.15095
# test loss: 0.09267
# epoch: 20 loss: 0.08291
# test loss: 0.07117
# epoch: 30 loss: 0.05806
# test loss: 0.04796
# epoch: 40 loss: 0.04508
# test loss: 0.03046
# epoch: 50 loss: 0.03862
# test loss: 0.03750
# epoch: 60 loss: 0.03790
# test loss: 0.04039
# epoch: 70 loss: 0.03404
# test loss: 0.03365
# epoch: 80 loss: 0.03447
# test loss: 0.03826
# epoch: 90 loss: 0.03485
# test loss: 0.03378
# epoch: 100 loss: 0.03409
# test loss: 0.03687
# epoch: 110 loss: 0.03584
# test loss: 0.03148
# epoch: 120 loss: 0.03539
# test loss: 0.03041
# epoch: 130 loss: 0.03538
# test loss: 0.02445
# epoch: 140 loss: 0.03486
# test loss: 0.03152
# epoch: 150 loss: 0.03580
# test loss: 0.03764
# epoch: 160 loss: 0.03299
# test loss: 0.03300
# epoch: 170 loss: 0.03276
# test loss: 0.03301
# epoch: 180 loss: 0.03420
# test loss: 0.03596
# epoch: 190 loss: 0.03454
# test loss: 0.02594
# epoch: 200 loss: 0.03133
# test loss: 0.03750
# epoch: 210 loss: 0.02891
# test loss: 0.01562
# epoch: 220 loss: 0.01937
# test loss: 0.04135
# epoch: 230 loss: 0.01839
# test loss: 0.01356
# epoch: 240 loss: 0.01689
# test loss: 0.01813
# epoch: 250 loss: 0.01784
# test loss: 0.01194
# epoch: 260 loss: 0.01702
# test loss: 0.01266
# epoch: 270 loss: 0.01514
# test loss: 0.01072
# epoch: 280 loss: 0.01586
# test loss: 0.01771
# epoch: 290 loss: 0.01665
# test loss: 0.00900
# epoch: 300 loss: 0.01441
# test loss: 0.01963
# epoch: 310 loss: 0.01640
# test loss: 0.01652
# epoch: 320 loss: 0.01815
# test loss: 0.01050
# epoch: 330 loss: 0.01771
# test loss: 0.01917
# epoch: 340 loss: 0.01668
# test loss: 0.01175
# epoch: 350 loss: 0.01651
# test loss: 0.01459
# epoch: 360 loss: 0.01697
# test loss: 0.01013
# epoch: 370 loss: 0.01463
# test loss: 0.01135
# epoch: 380 loss: 0.01535
# test loss: 0.01863
# epoch: 390 loss: 0.01600
# test loss: 0.01554
# epoch: 400 loss: 0.01614
# test loss: 0.00971
# epoch: 410 loss: 0.01657
# test loss: 0.02090
# epoch: 420 loss: 0.01543
# test loss: 0.00885
# epoch: 430 loss: 0.01639
# test loss: 0.01053
# epoch: 440 loss: 0.01596
# test loss: 0.03479
# epoch: 450 loss: 0.01519
# test loss: 0.01382
# epoch: 460 loss: 0.01402
# test loss: 0.01329
# epoch: 470 loss: 0.01464
# test loss: 0.00717
# epoch: 480 loss: 0.01798
# test loss: 0.00824
# epoch: 490 loss: 0.01797
# test loss: 0.01448
# epoch: 500 loss: 0.01541
# test loss: 0.01123
# epoch: 510 loss: 0.01611
# test loss: 0.04156
# epoch: 520 loss: 0.01629
# test loss: 0.01376
# epoch: 530 loss: 0.01534
# test loss: 0.00908
# epoch: 540 loss: 0.01394
# test loss: 0.01365
# epoch: 550 loss: 0.01529
# test loss: 0.00792
# epoch: 560 loss: 0.01475
# test loss: 0.00778
# epoch: 570 loss: 0.01557
# test loss: 0.00824
# epoch: 580 loss: 0.01364
# test loss: 0.01582
# epoch: 590 loss: 0.01494
# test loss: 0.01050
# epoch: 600 loss: 0.01526
# test loss: 0.02152
# epoch: 610 loss: 0.01577
# test loss: 0.00905
# epoch: 620 loss: 0.01441
# test loss: 0.00879
# epoch: 630 loss: 0.01443
# test loss: 0.00827
# epoch: 640 loss: 0.01538
# test loss: 0.04280
# epoch: 650 loss: 0.01465
# test loss: 0.00573
# epoch: 660 loss: 0.01536
# test loss: 0.04370
# epoch: 670 loss: 0.01343
# test loss: 0.01809
# epoch: 680 loss: 0.01380
# test loss: 0.01225
# epoch: 690 loss: 0.01308
# test loss: 0.00659
# epoch: 700 loss: 0.01461
# test loss: 0.00672
# epoch: 710 loss: 0.01430
# test loss: 0.00617
# epoch: 720 loss: 0.01481
# test loss: 0.00862
# epoch: 730 loss: 0.01542
# test loss: 0.00984
# epoch: 740 loss: 0.01523
# test loss: 0.01029
# epoch: 750 loss: 0.01423
# test loss: 0.00861
# epoch: 760 loss: 0.01352
# test loss: 0.00907
# epoch: 770 loss: 0.01348
# test loss: 0.01049
# epoch: 780 loss: 0.01365
# test loss: 0.01010
# epoch: 790 loss: 0.01440
# test loss: 0.01224
# epoch: 800 loss: 0.01655
# test loss: 0.01032
# epoch: 810 loss: 0.01381
# test loss: 0.03176
# epoch: 820 loss: 0.01214
# test loss: 0.00908
# epoch: 830 loss: 0.01253
# test loss: 0.02323
# epoch: 840 loss: 0.01205
# test loss: 0.00797
# epoch: 850 loss: 0.01275
# test loss: 0.00792
# epoch: 860 loss: 0.01395
# test loss: 0.01495
# epoch: 870 loss: 0.01336
# test loss: 0.03813
# epoch: 880 loss: 0.01267
# test loss: 0.03806
# epoch: 890 loss: 0.01224
# test loss: 0.00774
# epoch: 900 loss: 0.01299
# test loss: 0.00612
# epoch: 910 loss: 0.01379
# test loss: 0.00814
# epoch: 920 loss: 0.01259
# test loss: 0.01121
# epoch: 930 loss: 0.01239
# test loss: 0.01028
# epoch: 940 loss: 0.01280
# test loss: 0.00635
# epoch: 950 loss: 0.01301
# test loss: 0.00580
# epoch: 960 loss: 0.01272
# test loss: 0.00948
# epoch: 970 loss: 0.01096
# test loss: 0.00778
# epoch: 980 loss: 0.01231
# test loss: 0.01414
# epoch: 990 loss: 0.01156
# test loss: 0.01200
# epoch: 1000 loss: 0.01140
# test loss: 0.00487
# epoch: 1010 loss: 0.01370
# test loss: 0.01990
# epoch: 1020 loss: 0.01366
# test loss: 0.01002
# epoch: 1030 loss: 0.01454
# test loss: 0.00919
# epoch: 1040 loss: 0.01371
# test loss: 0.00628
# epoch: 1050 loss: 0.01369
# test loss: 0.01218
# epoch: 1060 loss: 0.01261
# test loss: 0.00566
# epoch: 1070 loss: 0.01238
# test loss: 0.00609
# epoch: 1080 loss: 0.01121
# test loss: 0.00694
# epoch: 1090 loss: 0.00956
# test loss: 0.00610
# epoch: 1100 loss: 0.01118
# test loss: 0.00950
# epoch: 1110 loss: 0.01194
# test loss: 0.04055
# epoch: 1120 loss: 0.01299
# test loss: 0.01624
# epoch: 1130 loss: 0.01132
# test loss: 0.00613
# epoch: 1140 loss: 0.01272
# test loss: 0.02027
# epoch: 1150 loss: 0.01231
# test loss: 0.00642
# epoch: 1160 loss: 0.01154
# test loss: 0.01911
# epoch: 1170 loss: 0.01225
# test loss: 0.00979
# epoch: 1180 loss: 0.01108
# test loss: 0.00566
# epoch: 1190 loss: 0.01100
# test loss: 0.00491
# epoch: 1200 loss: 0.01173
# test loss: 0.01147
# epoch: 1210 loss: 0.01166
# test loss: 0.00521
# epoch: 1220 loss: 0.01015
# test loss: 0.03227
# epoch: 1230 loss: 0.01189
# test loss: 0.02045
# epoch: 1240 loss: 0.01219
# test loss: 0.00576
# epoch: 1250 loss: 0.01091
# test loss: 0.00726
# epoch: 1260 loss: 0.01174
# test loss: 0.01260
# epoch: 1270 loss: 0.01159
# test loss: 0.00707
# epoch: 1280 loss: 0.01073
# test loss: 0.02330
# epoch: 1290 loss: 0.01164
# test loss: 0.00788
# epoch: 1300 loss: 0.01428
# test loss: 0.00747
# epoch: 1310 loss: 0.01531
# test loss: 0.01420
# epoch: 1320 loss: 0.01429
# test loss: 0.00539
# epoch: 1330 loss: 0.01258
# test loss: 0.01357
# epoch: 1340 loss: 0.01077
# test loss: 0.04690
# epoch: 1350 loss: 0.01310
# test loss: 0.00698
# epoch: 1360 loss: 0.01140
# test loss: 0.00735
# epoch: 1370 loss: 0.01132
# test loss: 0.00916
# epoch: 1380 loss: 0.01260
# test loss: 0.01438
# epoch: 1390 loss: 0.01197
# test loss: 0.00800
# epoch: 1400 loss: 0.01277
# test loss: 0.00493
# epoch: 1410 loss: 0.01299
# test loss: 0.00632
# epoch: 1420 loss: 0.01254
# test loss: 0.01388
# epoch: 1430 loss: 0.01283
# test loss: 0.01208
# epoch: 1440 loss: 0.01109
# test loss: 0.01480
# epoch: 1450 loss: 0.01090
# test loss: 0.00498
# epoch: 1460 loss: 0.01175
# test loss: 0.00576
# epoch: 1470 loss: 0.01219
# test loss: 0.01564
# epoch: 1480 loss: 0.01016
# test loss: 0.00477
# epoch: 1490 loss: 0.01262
# test loss: 0.00864
# epoch: 1500 loss: 0.01292
# test loss: 0.01848
# epoch: 1510 loss: 0.01126
# test loss: 0.00968
# epoch: 1520 loss: 0.01140
# test loss: 0.00489
# epoch: 1530 loss: 0.01132
# test loss: 0.00547
# epoch: 1540 loss: 0.01226
# test loss: 0.00662
# epoch: 1550 loss: 0.01188
# test loss: 0.00828
# epoch: 1560 loss: 0.01193
# test loss: 0.01090
# epoch: 1570 loss: 0.01021
# test loss: 0.00798
# epoch: 1580 loss: 0.01457
# test loss: 0.01158
# epoch: 1590 loss: 0.01460
# test loss: 0.06544
# epoch: 1600 loss: 0.01081
# test loss: 0.00594
# epoch: 1610 loss: 0.01071
# test loss: 0.00710
# epoch: 1620 loss: 0.01198
# test loss: 0.00502
# epoch: 1630 loss: 0.01252
# test loss: 0.04066
# epoch: 1640 loss: 0.01086
# test loss: 0.00518
# epoch: 1650 loss: 0.01163
# test loss: 0.01789
# epoch: 1660 loss: 0.00921
# test loss: 0.00673
# epoch: 1670 loss: 0.00951
# test loss: 0.01232
# epoch: 1680 loss: 0.01056
# test loss: 0.01984
# epoch: 1690 loss: 0.01108
# test loss: 0.01208
# epoch: 1700 loss: 0.01048
# test loss: 0.00844
# epoch: 1710 loss: 0.01016
# test loss: 0.01348
# epoch: 1720 loss: 0.00959
# test loss: 0.00474
# epoch: 1730 loss: 0.01117
# test loss: 0.00591
# epoch: 1740 loss: 0.01112
# test loss: 0.00637
# epoch: 1750 loss: 0.01108
# test loss: 0.01373

# %%
# torch.save(model.state_dict(), "Only_romo_lif_refrac_net")

# %%
if False:
    model.load_state_dict(torch.load("Only_dm_lif_net"))

# %%
inputs, target_outputs = Task_test.dataset(30)
inputs += np.random.normal(0, 0.01, size=(inputs.shape))
inputs = torch.from_numpy(inputs).type(torch.float).to(device)
target_outputs = torch.from_numpy(target_outputs).type(torch.float).to(device)
outputs, states = model(inputs)

# %%
# %matplotlib inline
for i in range(inputs.shape[2]):
    plt.plot(inputs[:, 0, i].detach().cpu().numpy(), label=fr"$u_{i + 1}$")
    plt.legend()
    plt.show()
    plt.close()
for i in range(outputs.shape[2]):
    plt.plot(outputs[:, 0, i].detach().cpu().numpy(), label=fr"$u_{i + 1}$")
    plt.plot(
        target_outputs[:, 0, i].detach().cpu().numpy(), label=fr"$u^{{target}}_{i + 1}$"
    )
    plt.legend()
    plt.show()
    plt.close()

plt.plot(
    outputs[:, 0, -2].detach().cpu().numpy() - outputs[:, 0, -1].detach().cpu().numpy(),
    label=fr"$u_2 - u_3$",
)
plt.plot(target_outputs[:, 0, -2].detach().cpu().numpy(), label=fr"$u^{{target}}_{2}$")
plt.plot(target_outputs[:, 0, -1].detach().cpu().numpy(), label=fr"$u^{{target}}_{3}$")
plt.legend()
plt.show()
plt.close()

# %%
# %matplotlib inline
for i in range(inputs.shape[2]):
    plt.plot(inputs[:, 0, i].detach().cpu().numpy(), label=fr"$u_{i + 1}$")

plt.legend()
plt.show()
plt.close()
plt.plot(target_outputs[:, 0, 1].detach().cpu().numpy(), label=fr"$y_{2}$")
plt.plot(target_outputs[:, 0, 2].detach().cpu().numpy(), label=fr"$y_{3}$")

# %%
weights_post_l = []
with torch.no_grad():
    for name, param in model.named_parameters():
        if param.requires_grad:
            weights_post_l.append((param).cpu().numpy())

# %%
# %matplotlib inline
for i in range(len(weights_pre_l) - 1):
    plt.imshow((weights_pre_l[i]), aspect="auto", cmap="jet", vmin=-0.2, vmax=0.4)
    plt.colorbar()
    plt.show()

# %%
# %matplotlib inline
for i in range(len(weights_pre_l) - 1):
    plt.imshow((weights_post_l[i]), aspect="auto", cmap="jet", vmin=-0.2, vmax=0.4)
    plt.colorbar()
    plt.show()

# %%
# %matplotlib inline
for i in range(len(weights_pre_l) - 1):
    plt.imshow(
        (weights_post_l[i] - weights_pre_l[i]),
        aspect="auto",
        cmap="jet",
        vmin=-0.2,
        vmax=0.4,
    )
    plt.colorbar()
    plt.show()
