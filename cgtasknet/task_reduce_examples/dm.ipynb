# %% [markdown]
# # DM Task

# %%
from cgtasknet.tasks.reduce import (
    DMTask,
    DMTaskRandomMod,
    DMTask1,
    DMTask2,
    DefaultParams,
)
from plot_inputs_and_outputs import plot_inputs_outputs

# %%
Task = DMTask()
inputs, outputs = Task.dataset(10)
plot_inputs_outputs(inputs, outputs)
